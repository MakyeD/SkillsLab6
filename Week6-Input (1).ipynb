# %%
print("What is your name?")
name = input(str())
print("How many years old are you?")
age = input(int())
print("Okay, so your name is " + name + " and you are " + str(age)+ " years old.")
# Out:
# What is your name?
#  Makye
# How many years old are you?
# 0 18
# Okay, so your name is Makye and you are 18 years old.
